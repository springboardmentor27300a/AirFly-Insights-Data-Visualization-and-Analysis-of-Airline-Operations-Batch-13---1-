# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\college files\flights.csv",low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r"D:\college files\flights.csv",low_memory=False)
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
temp = df[df["CANCELLED"] == 1]
print(len(temp))
# Out:
# 89884

# %%
df.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# ...

# %%
df["TAIL_NUMBER"]
# Out:
# 0          N407AS
# 1          N3KUAA
# 2          N171US
# 3          N3HYAA
# 4          N527AS
#             ...
# 5819074    N657JB
# 5819075    N828JB
# 5819076    N913JB
# 5819077    N527JB
# 5819078    N534JB
# Name: TAIL_NUMBER, Length: 5819079, dtype: object

# %%
arr = df["TAIL_NUMBER"].unique()

# %%
print(len(arr))
# Out:
# 4898

# %%
temp = df[df["AIRLINE"]=="AA"]
temp
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1        2015      1    1            4      AA           2336      N3KUAA
# 3        2015      1    1            4      AA            258      N3HYAA
# 8        2015      1    1            4      AA           1112      N3LAAA
# 11       2015      1    1            4      AA           1674      N853AA
# 21       2015      1    1            4      AA            371      N3GXAA
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819031  2015     12   31            4      AA           1927      N837AW
# 5819035  2015     12   31            4      AA            675      N207UW
# 5819049  2015     12   31            4      AA           1538      N866AA
# 5819067  2015     12   31            4      AA           2342      N3DLAA
# 5819068  2015     12   31            4      AA            219      N3LYAA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
t_arr = temp["TAIL_NUMBER"].unique()

# %%
temp1 = df[(df["ORIGIN_AIRPORT"] == "MSO" ) & (df["DESTINATION_AIRPORT"] == "DEN")]

# %%
temp1.head(20)
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 297     2015      1    1            4      F9            865         NaN
# 2201    2015      1    1            4      OO           5534      N928SW
# 5849    2015      1    1            4      OO           5578      N943SW
# 10083   2015      1    1            4      OO           5519      N479CA
# 17475   2015      1    2            5      OO           5534      N969SW
# 21537   2015      1    2            5      OO           5535      N983SW
# 26060   2015      1    2            5      OO           5519      N905SW
# 31250   2015      1    3            6      F9            865      N910FR
# 33950   2015      1    3            6      OO           5534      N941SW
# 37732   2015      1    3            6      OO           5519      N702BR
# 46690   2015      1    4            7      F9            865      N918FR
# 49152   2015      1    4            7      OO           5534      N716SK
# ...

# %%
df["CANCELLATION_REASON"] = df["CANCELLATION_REASON"].fillna("N")

# %%
df.isnull().sum()
# Out:
# YEAR                        0
# MONTH                       0
# DAY                         0
# DAY_OF_WEEK                 0
# AIRLINE                     0
# FLIGHT_NUMBER               0
# TAIL_NUMBER             14721
# ORIGIN_AIRPORT              0
# DESTINATION_AIRPORT         0
# SCHEDULED_DEPARTURE         0
# DEPARTURE_TIME          86153
# DEPARTURE_DELAY         86153
# TAXI_OUT                89047
# WHEELS_OFF              89047
# SCHEDULED_TIME              6
# ELAPSED_TIME           105071
# AIR_TIME               105071
# DISTANCE                    0
# WHEELS_ON               92513
# TAXI_IN                 92513
# SCHEDULED_ARRIVAL           0
# ARRIVAL_TIME            92513
# ARRIVAL_DELAY          105071
# DIVERTED                    0
# CANCELLED                   0
# CANCELLATION_REASON         0
# AIR_SYSTEM_DELAY            0
# SECURITY_DELAY              0
# AIRLINE_DELAY               0
# LATE_AIRCRAFT_DELAY         0
# WEATHER_DELAY               0
# ...

# %%
df["CANCELLATION_REASON"] = "N"  # default

# %%
df["AIR_SYSTEM_DELAY"] = df["AIR_SYSTEM_DELAY"].fillna(0)
df["SECURITY_DELAY"] = df["SECURITY_DELAY"].fillna(0)
df["AIRLINE_DELAY"] = df["AIRLINE_DELAY"].fillna(0)
df["LATE_AIRCRAFT_DELAY"] = df["LATE_AIRCRAFT_DELAY"].fillna(0)
df["WEATHER_DELAY"] = df["WEATHER_DELAY"].fillna(0)

# %%
temp = df[df["TAXI_OUT"].isna()]

# %%
temp.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER            14721
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME         86153
# DEPARTURE_DELAY        86153
# TAXI_OUT               89047
# WHEELS_OFF             89047
# SCHEDULED_TIME             0
# ELAPSED_TIME           89047
# AIR_TIME               89047
# DISTANCE                   0
# WHEELS_ON              89047
# TAXI_IN                89047
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME           89047
# ARRIVAL_DELAY          89047
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON        0
# AIR_SYSTEM_DELAY           0
# SECURITY_DELAY             0
# AIRLINE_DELAY              0
# LATE_AIRCRAFT_DELAY        0
# WEATHER_DELAY              0
# dtype: int64

# %%
temp.head(20)
# Out:
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 32   2015      1    1            4      AS            136      N431AS
# 42   2015      1    1            4      AA           2459      N3BDAA
# 68   2015      1    1            4      OO           5254      N746SK
# 82   2015      1    1            4      MQ           2859      N660MQ
# 90   2015      1    1            4      OO           5460      N583SW
# 128  2015      1    1            4      MQ           2926      N932MQ
# 131  2015      1    1            4      OO           6457      N560SW
# 147  2015      1    1            4      MQ           3534      N925MQ
# 166  2015      1    1            4      MQ           3161      N5PBMQ
# 206  2015      1    1            4      AA            175      N3EWAA
# 210  2015      1    1            4      AA           1103      N3HCAA
# 213  2015      1    1            4      AA           1055      N573AA
# ...

# %%
df["TAIL_NUMBER"] = df["TAIL_NUMBER"].fillna("Cancel")

# %%
df["DEPARTURE_TIME"] = df["DEPARTURE_TIME"].fillna(0)
df["DEPARTURE_DELAY"] = df["DEPARTURE_DELAY"].fillna(0)
df["TAXI_OUT"] = df["TAXI_OUT"].fillna(0)
df["WHEELS_OFF"] = df["WHEELS_OFF"].fillna(0)
df["ELAPSED_TIME"] = df["ELAPSED_TIME"].fillna(0)
df["AIR_TIME"] = df["AIR_TIME"].fillna(0)
df["WHEELS_ON"] = df["WHEELS_ON"].fillna(0)
df["ARRIVAL_TIME"] = df["ARRIVAL_TIME"].fillna(0)
df["ARRIVAL_DELAY"] = df["ARRIVAL_DELAY"].fillna(0)
df["TAXI_IN"] = df["TAXI_IN"].fillna(0)

# %%
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER            14721
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME             0
# DEPARTURE_DELAY            0
# TAXI_OUT                   0
# WHEELS_OFF                 0
# SCHEDULED_TIME             6
# ELAPSED_TIME               0
# AIR_TIME                   0
# DISTANCE                   0
# WHEELS_ON                  0
# TAXI_IN                    0
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME               0
# ARRIVAL_DELAY              0
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON        0
# AIR_SYSTEM_DELAY           0
# SECURITY_DELAY             0
# AIRLINE_DELAY              0
# LATE_AIRCRAFT_DELAY        0
# WEATHER_DELAY              0
# dtype: int64

# %%
 
 
columns_to_remove = [
    'FLIGHT_NUMBER',
    'TAIL_NUMBER',
    'SCHEDULED_DEPARTURE',
    'DEPARTURE_TIME',
    'TAXI_OUT',
    'WHEELS_OFF',
    'SCHEDULED_TIME',
    'ELAPSED_TIME',
    'AIR_TIME',
    'WHEELS_ON',
    'TAXI_IN',
    'SCHEDULED_ARRIVAL',
    'ARRIVAL_TIME'
]

 
df = df.drop(columns=columns_to_remove)

 
print(df.columns)
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'DEPARTURE_DELAY', 'DISTANCE', 'ARRIVAL_DELAY',
#        'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY',
#        'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'WEATHER_DELAY'],
#       dtype='object')

# %%
df.to_csv("cleaned_flight_data.csv", index=False)
